# %%
import pandas as pd

# %%
import random
age=[]
height=[]
weight=[]
speed=[]
for _ in range(100):
  age.append(random.randint(0,100))
  height.append(random.randint(0,100))
  weight.append(random.randint(0,100))
  speed.append(random.randint(0,100))
  idata={'Age':age,'Height': height,'Weight':weight,'Speed':speed}

# %%
df1 = pd.DataFrame(idata)

# %%
df1
# Out:
#     Age  Height  Weight  Speed
# 0    59      58      11     76
# 1    69      39      74     44
# 2    82      36      51      0
# 3    44      71      90     13
# 4    63      56       2     52
# ..  ...     ...     ...    ...
# 95   75      30      93     43
# 96   49      75      17     78
# 97   23       5      61     49
# 98   20      32       6     35
# 99   68      98      95      9
#
# [100 rows x 4 columns]

# %%
df1[['Age','Height']]
# Out:
#     Age  Height
# 0    59      58
# 1    69      39
# 2    82      36
# 3    44      71
# 4    63      56
# ..  ...     ...
# 95   75      30
# 96   49      75
# 97   23       5
# 98   20      32
# 99   68      98
#
# [100 rows x 2 columns]

# %%
 df1.loc[[0,3],['Age','Height']]
# Out:
#    Age  Height
# 0   59      58
# 3   44      71

# %%
df2=df1[['Age','Height']]

# %%
df2
# Out:
#     Age  Height
# 0    59      58
# 1    69      39
# 2    82      36
# 3    44      71
# 4    63      56
# ..  ...     ...
# 95   75      30
# 96   49      75
# 97   23       5
# 98   20      32
# 99   68      98
#
# [100 rows x 2 columns]

# %%
df2.describe()
# Out:
#               Age      Height
# count  100.000000  100.000000
# mean    57.010000   46.720000
# std     25.635162   29.152015
# min      1.000000    3.000000
# 25%     37.750000   23.750000
# 50%     60.000000   42.000000
# 75%     77.000000   73.000000
# max    100.000000  100.000000

# %%
df1
# Out:
#     Age  Height  Weight  Speed
# 0    59      58      11     76
# 1    69      39      74     44
# 2    82      36      51      0
# 3    44      71      90     13
# 4    63      56       2     52
# ..  ...     ...     ...    ...
# 95   75      30      93     43
# 96   49      75      17     78
# 97   23       5      61     49
# 98   20      32       6     35
# 99   68      98      95      9
#
# [100 rows x 4 columns]
